# %%
from z3 import *
def b(x):
    return bin(x)[2:].rjust(32, '0')

cA = {}
cW = {}

# 0, 1, +, -: self explanatory
# x: flip the bit
# ^: Qt[b] == Qt-1[b]
# !: Qt[b] != Qt-1[b]
# r: Qt[b] == RL(Qt-1,30)[b]
# R: Qt[b] != RL(Qt-1,30)[b]
# m: Qt[b] == RL(Qt-2,30)[b]
# #: Qt[b] != RL(Qt-2,30)[b]


for ln in open('ms_char').read().split("\n"):
    lnn = ln.split(" ")
    if len(lnn) > 1:
        rnd = int(lnn[0][:-1])
        cA[rnd] = lnn[1]
        if len(lnn) == 3:
            cW[rnd] = lnn[2]
        print lnn

#print cA
#print W
# Out:
# ['-4:', '................................']
# ['-3:', '................................']
# ['-2:', '................................']
# ['-1:', '...1........................0...']
# ['0:', '.^.0.1.......0.1...00.10.1..1..1', '....++........................+.']
# ['1:', '.0.+^-^^^^^^^1^0^^^11^10.0..1.+0', 'x-.........................-....']
# ['2:', '1-...+--------------------.-1.+0', 'x.++.-.....................-+-..']
# ['3:', '.-.-.0.11111111111110++1+-1-00-0', '..-+++.......................-..']
# ['4:', '.-...1.0111111111111-+++++0.1.+1', 'x.---+.....................+-.+.']
# ['5:', '.-...0................0..+.+10+0', '..-........................-....']
# ['6:', '.-.+..................01100-.0+.', '..-..+.....................+++..']
# ['7:', '-1...1.....................0.0..', 'x++.--.....................+.+..']
# ['8:', '1.1-.1.......................1..', '....-+........................-.']
# ['9:', '..-..0..........................', 'x+.........................-....']
# ['10:', '^...00.........................1', 'x.+-.-.....................+--..']
# ['11:', '..-.1..........................0', '..-.+-.......................+..']
# ['12:', '0-..1.........................!.', 'x.+---.....................+-...']
# ['13:', '+..01...........................', 'x.++.......................-....']
# ['14:', '..-1..........................!.', '............................+-..']
# ['15:', '+.0.1.........................!^', 'x.---......................-....']
# ['16:', '+-0.0.........................!.', '....-......................-+...']
# ['17:', '+..1..........................^.', '.+---......................-....']
# ['18:', '-.+0............................', '....-......................+.-..']
# ['19:', '-...m...........................', '.-++.......................+....']
# ['20:', '..+.r...........................', 'x.-+-......................-++..']
# ['21:', '^.r.m...........................', 'x++.-...........................']
# ['22:', '..+.r...........................', 'x.++.........................-..']
# ['23:', '-...m..........................!', '.-.++......................+....']
# ['24:', '.-+.R...........................', 'x.-+........................+-..']
# ['25:', '..r##...........................', '.-..+...........................']
# ['26:', '...rr...........................', 'x.+-............................']
# ['27:', '-...............................']
# ['28:', '-.#.............................']
# ['29:', '................................']
# ['30:', '..R.............................']

# %%
# encode characteristics
def encode_characteristic(s, rnd, z0, z1, char):
    if len(z0) <= rnd:
        return
    mask = 0
    nnmask = 0
    b0 = 0
    b1 = 0
    for i in range(32):
        c = char[31-i]
        if c == "0":
            mask |= 1<<i
        elif c == "1":
            b0 |= 1<<i
            b1 |= 1<<i
            mask |= 1<<i
        elif c == "-":
            b0 |= 1<<i
            mask |= 1<<i
        elif c == "+":
            b1 |= 1<<i
            mask |= 1<<i
        elif c == "x":
            s.add((z0[rnd]&(1<<i)) != (z1[rnd]&(1<<i)))
            nnmask |= 1<<i
        elif c == "^": # ^: Qt[b] == Qt-1[b]
            s.add((z0[rnd]&(1<<i)) == (z0[rnd-1]&(1<<i)))
            s.add((z1[rnd]&(1<<i)) == (z1[rnd-1]&(1<<i)))
            nnmask |= 1<<i
        elif c == "!": # !: Qt[b] != Qt-1[b]
            s.add((z0[rnd]&(1<<i)) != (z0[rnd-1]&(1<<i)))
            s.add((z1[rnd]&(1<<i)) != (z1[rnd-1]&(1<<i)))
            nnmask |= 1<<i
        """
        elif c == "r": # ^: Qt[b] == RL(Qt-1,30)[b]
            s.add((z0[rnd]&(1<<i)) == (z0[rnd-1]&(1<<((i+30) % 32))))
            s.add((z1[rnd]&(1<<i)) == (z1[rnd-1]&(1<<((i+30) % 32))))
            nnmask |= 1<<i
        elif c == "R": # !: Qt[b] != RL(Qt-1,30)[b]
            s.add((z0[rnd]&(1<<i)) == (z0[rnd-1]&(1<<((i+30) % 32))))
            s.add((z1[rnd]&(1<<i)) == (z1[rnd-1]&(1<<((i+30) % 32))))
            nnmask |= 1<<i
        elif c == "m": # ^: Qt[b] == RL(Qt-2,30)[b]
            s.add((z0[rnd]&(1<<i)) == (z0[rnd-2]&(1<<((i+30) % 32))))
            s.add((z1[rnd]&(1<<i)) == (z1[rnd-2]&(1<<((i+30) % 32))))
            nnmask |= 1<<i
        elif c == "#": # !: Qt[b] != RL(Qt-2,30)[b]
            s.add((z0[rnd]&(1<<i)) == (z0[rnd-2]&(1<<((i+30) % 32))))
            s.add((z1[rnd]&(1<<i)) == (z1[rnd-2]&(1<<((i+30) % 32))))
            nnmask |= 1<<i
        """

    nmask = mask ^ 0xFFFFFFFF
    nmask &= nnmask ^ 0xFFFFFFFF
    
    # need to encode ^ and !
    s.add((z0[rnd]&mask) == b0)
    s.add((z1[rnd]&mask) == b1)
    
    s.add(z0[rnd]&nmask == z1[rnd]&nmask)
    
    return mask, b0, b1


# encode rules of SHA-1
def encode_sha1(a, w, f, count):
    for i in range(count):
        # encode w
        if i >= 16:
            w.append(RotateLeft(w[-3] ^ w[-8] ^ w[-14] ^ w[-16], 1))
            pass
        
        # encode f
        b = a[-2]
        c = RotateLeft(a[-3], 30)
        d = RotateLeft(a[-4], 30)
        
        if i < 20:
            # if
            f.append(d ^ (b & (c ^ d)))
        elif i < 40 or i >= 60:
            # xor
            f.append(b ^ c ^ d)
        else:
            # maj
            f.append((b&c) ^ (b&d) ^ (c&d))
        
        k = [0x5a827999, 0x6ed9eba1, 0x8f1bbcdc, 0xca62c1d6][i/20]
            
        # encode a
        temp = RotateLeft(a[-1], 5) + f[-1] + RotateLeft(a[-5], 30) + w[i] + k
        a.append(temp)

# %%
# create the variables

zF_0 = []
zF_1 = []

zW_0 = []
zW_1 = []
for i in range(16):
    zW_0.append(BitVec('W_0_%d' % i, 32))
    zW_1.append(BitVec('W_1_%d' % i, 32))

zA_0 = []
zA_1 = []
for i in range(-4, 1):
    zA_0.append(BitVec('A_0_%d' % i, 32))
    zA_1.append(BitVec('A_1_%d' % i, 32))
    
encode_sha1(zA_0, zW_0, zF_0, 28)
encode_sha1(zA_1, zW_1, zF_1, 28)

# %%
# test sha-1
s = Solver()

iv = [0b01111101001100010100100011010000,
      0b11011100111110111100100111011100,
      0b11100011100011101101111101000010,
      0b01111111110101011011111001110001,
      0b11001100001110110110011001011001]

[encode_characteristic(s, rnd+4, zA_0, zA_1, cA[rnd]) for rnd in cA]
[encode_characteristic(s, rnd+0, zW_0, zW_1, cW[rnd]) for rnd in cW]

[s.add(zA_0[i] == iv[i]) for i in range(5)]

#[s.add(zA_0[rnd] == int(a, 2)) for rnd, a in zip(range(len(zA_0)), open("ms_example").read().split("\n"))]

s.check()
# Out:
# sat

# %%
m = s.model()

W0 = [m[zW_0[i]].as_long() for i in range(16)]
W1 = [m[zW_1[i]].as_long() for i in range(16)]

from collide import sha1, expand

Q0 = sha1(expand(W0), iv)
Q1 = sha1(expand(W1), iv)

for i in range(len(cA)+10):
    print b(Q0[i]), b(Q1[i]), "%3d" % (i-4), b(Q0[i]^Q1[i]), "" if i >= len(cA) else cA[i-4]
# Out:
# 01111101001100010100100011010000 01111101001100010100100011010000  -4 00000000000000000000000000000000 ................................
# 11011100111110111100100111011100 11011100111110111100100111011100  -3 00000000000000000000000000000000 ................................
# 11100011100011101101111101000010 11100011100011101101111101000010  -2 00000000000000000000000000000000 ................................
# 01111111110101011011111001110001 01111111110101011011111001110001  -1 00000000000000000000000000000000 ...1........................0...
# 11001100001110110110011001011001 11001100001110110110011001011001   0 00000000000000000000000000000000 .^.0.1.......0.1...00.10.1..1..1
# 00001100001111100111111000001000 00011000001111100111111000001010   1 00010100000000000000000000000010 .0.+^-^^^^^^^1^0^^^11^10.0..1.+0
# 11110011111111111111111111011100 10110100000000000000000000001110   2 01000111111111111111111111010010 1-...+--------------------.-1.+0
# 01110011111111111111000101110010 00100011111111111111011110100000   3 01010000000000000000011011010010 .-.-.0.11111111111110++1+-1-00-0
# 11011110111111111111100000011001 10011110111111111111011111011011   4 01000000000000000000111111000010 .-...1.0111111111111-+++++0.1.+1
# 01011000011100000001100000001000 00011000011100000001100001011010   5 01000000000000000000000001010010 .-...0................0..+.+10+0
# 11100001011001100100000110011001 10110001011001100100000110001011   6 01010000000000000000000000010010 .-.+..................01100-.0+.
# 11000100001110111011110111000000 01000100001110111011110111000000   7 10000000000000000000000000000000 -1...1.....................0.0..
# 10110100011001111111101111111101 10100100011001111111101111111101   8 00010000000000000000000000000000 1.1-.1.......................1..
# 10101010011000110000110011000101 10001010011000110000110011000101   9 00100000000000000000000000000000 ..-..0..........................
# 11110000000100010011011111011111 11110000000100010011011111011111  10 00000000000000000000000000000000 ^...00.........................1
# 01101100000100000000001000100000 01001100000100000000001000100000  11 00100000000000000000000000000000 ..-.1..........................0
# 01011110101010100111100111110111 00011110101010100111100111110111  12 01000000000000000000000000000000 0-..1.........................!.
# 00101011001011010010000110000000 10101011001011010010000110000000  13 10000000000000000000000000000000 +..01...........................
# 10110000101000100111100110101110 10010000101000100111100110101110  14 00100000000000000000000000000000 ..-1..........................!.
# 01011000001111011111111010100100 11011000001111011111111010100100  15 10000000000000000000000000000000 +.0.1.........................!^
# 01000000111110000001111100001111 10000000111110000001111100001111  16 11000000000000000000000000000000 +-0.0.........................!.
# 00110100000110111011101001110010 10110100000110111011101001110010  17 10000000000000000000000000000000 +..1..........................^.
# 11001110001101110000110111000001 01101110001101110000110111000001  18 10100000000000000000000000000000 -.+0............................
# 10001001010001100110010101010111 00001001010001100110010101010111  19 10000000000000000000000000000000 -...m...........................
# 10000000110000110011111000111111 10100000110000110011111000111111  20 00100000000000000000000000000000 ..+.r...........................
# 10110111110010110100101111000001 10110111110010110100101111000001  21 00000000000000000000000000000000 ^.r.m...........................
# 10001110111101001001000110101100 10101110111101001001000110101100  22 00100000000000000000000000000000 ..+.r...........................
# 11111100111011000011110000100001 01111100111011000011110000100001  23 10000000000000000000000000000000 -...m..........................!
# 01010010111000001001000101110110 00110010111000001001000101110110  24 01100000000000000000000000000000 .-+.R...........................
# 01000110101011011010000011001011 01000110101011011010000011001011  25 00000000000000000000000000000000 ..r##...........................
# 10000100100011100011010110101111 10000100100011100011010110101111  26 00000000000000000000000000000000 ...rr...........................
# 11100111111000000111011100100001 01100111111000000111011100100001  27 10000000000000000000000000000000 -...............................
# 11000100100011000011010110001010 01000100100011000011010110001010  28 10000000000000000000000000000000 -.#.............................
# 01001000110000011110111110100001 00101000110000011110111110000001  29 01100000000000000000000000100000 ................................
# 00000111011010001101101110001111 01000111011010001101011110001011  30 01000000000000000000110000000100 ..R.............................
# 11110110101110010111010100111110 01010110101110001111010011100110  31 10100000000000011000000111011000
# 10011000011011001101110011111001 00110000010111001100010111101001  32 10101000001100000001100100010000
# 00101001011000001010101010111000 10001111010111010100101101011010  33 10100110001111011110000111100010
# 11100001011100100111000011001110 10101001000101101001101011101111  34 01001000011001001110101000100001
# 10011010010110101010000011011000 00000010111011100110101001010000  35 10011000101101001100101010001000
# 10011111110100100111110111011011 01000011111100010001100010010111  36 11011100001000110110010101001100
# 00111100010000010010111001110100 11101001001011110000100000001101  37 11010101011011100010011001111001
# 11100111110101110000101000011101 10100111000010000100000001010101  38 01000000110111110100101001001000
# 10111011000001101100011101100001 00001111010111000101010001011001  39 10110100010110101001001100111000
# 00101101111110011001111010000010 10110001010111000001010101000111  40 10011100101001011000101111000101

# %%
g = Goal()

[encode_characteristic(g, rnd+4, zA_0, zA_1, cA[rnd]) for rnd in cA]
[encode_characteristic(g, rnd+0, zW_0, zW_1, cW[rnd]) for rnd in cW]

[g.add(zA_0[i] == iv[i]) for i in range(5)]

t = Then('simplify', 'bit-blast', 'tseitin-cnf')
subgoal = t(g)
assert len(subgoal) == 1

"""
f = open("formula", "w")
for c in subgoal[0]:
    f.write(str(c) + "\n")
f.close()    
"""
"""


W0 = []
W1 = []

for i in range(16):
    w0 = m[zW_0[i]].as_long()
    w1 = m[zW_1[i]].as_long()
    W0.append(w0)
    W1.append(w1)
    print b(w0), b(w1), "    ", b(w0^w1)
"""
pass

# %%
"""
for i in range(3):
    mask, b0, b1 = encode_characteristic(s, i, zW_0, zW_1, cW[i])
    print i
    print b(mask)
    print b(b0)
"""

"""
rnd = 0
for a in open("ms_example").read().split("\n"):
    #if len(zA_0) <= rnd:
        #break
    if rnd >= 5:
        break
    s.add(zA_0[rnd] == int(a, 2))
    rnd += 1
"""

# %%
# Out:
# Or(k!46533, Not(k!46565))
