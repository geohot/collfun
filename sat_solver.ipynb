# %%
from z3 import *
def b(x):
    return bin(x)[2:].rjust(32, '0')

cA = {}
cW = {}

# 0, 1, +, -: self explanatory
# x: flip the bit
# ^: Qt[b] == Qt-1[b]
# !: Qt[b] != Qt-1[b]
# r: Qt[b] == RL(Qt-1,30)[b]
# R: Qt[b] != RL(Qt-1,30)[b]
# m: Qt[b] == RL(Qt-2,30)[b]
# #: Qt[b] != RL(Qt-2,30)[b]


for ln in open('ms_char').read().split("\n"):
    lnn = ln.split(" ")
    if len(lnn) > 1:
        rnd = int(lnn[0][:-1])
        cA[rnd] = lnn[1]
        if len(lnn) == 3:
            cW[rnd] = lnn[2]
        print lnn

#print cA
#print W
# Out:
# ['-4:', '................................']
# ['-3:', '................................']
# ['-2:', '................................']
# ['-1:', '...1........................0...']
# ['0:', '.^.0.1.......0.1...00.10.1..1..1', '....++........................+.']
# ['1:', '.0.+^-^^^^^^^1^0^^^11^10.0..1.+0', 'x-.........................-....']
# ['2:', '1-...+--------------------.-1.+0', 'x.++.-.....................-+-..']
# ['3:', '.-.-.0.11111111111110++1+-1-00-0', '..-+++.......................-..']
# ['4:', '.-...1.0111111111111-+++++0.1.+1', 'x.---+.....................+-.+.']
# ['5:', '.-...0................0..+.+10+0', '..-........................-....']
# ['6:', '.-.+..................01100-.0+.', '..-..+.....................+++..']
# ['7:', '-1...1.....................0.0..', 'x++.--.....................+.+..']
# ['8:', '1.1-.1.......................1..', '....-+........................-.']
# ['9:', '..-..0..........................', 'x+.........................-....']
# ['10:', '^...00.........................1', 'x.+-.-.....................+--..']
# ['11:', '..-.1..........................0', '..-.+-.......................+..']
# ['12:', '0-..1.........................!.', 'x.+---.....................+-...']
# ['13:', '+..01...........................', 'x.++.......................-....']
# ['14:', '..-1..........................!.', '............................+-..']
# ['15:', '+.0.1.........................!^', 'x.---......................-....']
# ['16:', '+-0.0.........................!.', '....-......................-+...']
# ['17:', '+..1..........................^.', '.+---......................-....']
# ['18:', '-.+0............................', '....-......................+.-..']
# ['19:', '-...m...........................', '.-++.......................+....']
# ['20:', '..+.r...........................', 'x.-+-......................-++..']
# ['21:', '^.r.m...........................', 'x++.-...........................']
# ['22:', '..+.r...........................', 'x.++.........................-..']
# ['23:', '-...m..........................!', '.-.++......................+....']
# ['24:', '.-+.R...........................', 'x.-+........................+-..']
# ['25:', '..r##...........................', '.-..+...........................']
# ['26:', '...rr...........................', 'x.+-............................']
# ['27:', '-...............................']
# ['28:', '-.#.............................']
# ['29:', '................................']
# ['30:', '..R.............................']

# %%
# encode characteristics
def encode_characteristic(s, rnd, z0, z1, char):
    if len(z0) <= rnd:
        return
    mask = 0
    nnmask = 0
    b0 = 0
    b1 = 0
    for i in range(32):
        c = char[31-i]
        if c == "0":
            mask |= 1<<i
        elif c == "1":
            b0 |= 1<<i
            b1 |= 1<<i
            mask |= 1<<i
        elif c == "-":
            b0 |= 1<<i
            mask |= 1<<i
        elif c == "+":
            b1 |= 1<<i
            mask |= 1<<i
        elif c == "x":
            s.add((z0[rnd]&(1<<i)) != (z1[rnd]&(1<<i)))
            nnmask |= 1<<i
        elif c == "^": # ^: Qt[b] == Qt-1[b]
            s.add((z0[rnd]&(1<<i)) == (z0[rnd-1]&(1<<i)))
            s.add((z1[rnd]&(1<<i)) == (z1[rnd-1]&(1<<i)))
            nnmask |= 1<<i
        elif c == "!": # !: Qt[b] != Qt-1[b]
            s.add((z0[rnd]&(1<<i)) != (z0[rnd-1]&(1<<i)))
            s.add((z1[rnd]&(1<<i)) != (z1[rnd-1]&(1<<i)))
            nnmask |= 1<<i
        """
        elif c == "r": # ^: Qt[b] == RL(Qt-1,30)[b]
            s.add((z0[rnd]&(1<<i)) == (z0[rnd-1]&(1<<((i+30) % 32))))
            s.add((z1[rnd]&(1<<i)) == (z1[rnd-1]&(1<<((i+30) % 32))))
            nnmask |= 1<<i
        elif c == "R": # !: Qt[b] != RL(Qt-1,30)[b]
            s.add((z0[rnd]&(1<<i)) == (z0[rnd-1]&(1<<((i+30) % 32))))
            s.add((z1[rnd]&(1<<i)) == (z1[rnd-1]&(1<<((i+30) % 32))))
            nnmask |= 1<<i
        elif c == "m": # ^: Qt[b] == RL(Qt-2,30)[b]
            s.add((z0[rnd]&(1<<i)) == (z0[rnd-2]&(1<<((i+30) % 32))))
            s.add((z1[rnd]&(1<<i)) == (z1[rnd-2]&(1<<((i+30) % 32))))
            nnmask |= 1<<i
        elif c == "#": # !: Qt[b] != RL(Qt-2,30)[b]
            s.add((z0[rnd]&(1<<i)) == (z0[rnd-2]&(1<<((i+30) % 32))))
            s.add((z1[rnd]&(1<<i)) == (z1[rnd-2]&(1<<((i+30) % 32))))
            nnmask |= 1<<i
        """

    nmask = mask ^ 0xFFFFFFFF
    nmask &= nnmask ^ 0xFFFFFFFF
    
    # need to encode ^ and !
    s.add((z0[rnd]&mask) == b0)
    s.add((z1[rnd]&mask) == b1)
    
    s.add(z0[rnd]&nmask == z1[rnd]&nmask)
    
    return mask, b0, b1


# encode rules of SHA-1
def encode_sha1(a, w, f, count):
    for i in range(count):
        # encode w
        if i >= 16:
            w.append(RotateLeft(w[-3] ^ w[-8] ^ w[-14] ^ w[-16], 1))
            pass
        
        # encode f
        b = a[-2]
        c = RotateLeft(a[-3], 30)
        d = RotateLeft(a[-4], 30)
        
        if i < 20:
            # if
            f.append(d ^ (b & (c ^ d)))
        elif i < 40 or i >= 60:
            # xor
            f.append(b ^ c ^ d)
        else:
            # maj
            f.append((b&c) ^ (b&d) ^ (c&d))
        
        k = [0x5a827999, 0x6ed9eba1, 0x8f1bbcdc, 0xca62c1d6][i/20]
            
        # encode a
        temp = RotateLeft(a[-1], 5) + f[-1] + RotateLeft(a[-5], 30) + w[i] + k
        a.append(temp)

# %%
# create the variables

zF_0 = []
zF_1 = []

zW_0 = []
zW_1 = []
for i in range(16):
    zW_0.append(BitVec('W_0_%d' % i, 32))
    zW_1.append(BitVec('W_1_%d' % i, 32))

zA_0 = []
zA_1 = []
for i in range(-4, 1):
    zA_0.append(BitVec('A_0_%d' % i, 32))
    zA_1.append(BitVec('A_1_%d' % i, 32))
    
encode_sha1(zA_0, zW_0, zF_0, 25)
encode_sha1(zA_1, zW_1, zF_1, 25)

# %%
# test sha-1
s = Solver()

iv = [0b01111101001100010100100011010000,
      0b11011100111110111100100111011100,
      0b11100011100011101101111101000010,
      0b01111111110101011011111001110001,
      0b11001100001110110110011001011001]

[encode_characteristic(s, rnd+4, zA_0, zA_1, cA[rnd]) for rnd in cA]
[encode_characteristic(s, rnd+0, zW_0, zW_1, cW[rnd]) for rnd in cW]

[s.add(zA_0[i] == iv[i]) for i in range(5)]

#[s.add(zA_0[rnd] == int(a, 2)) for rnd, a in zip(range(len(zA_0)), open("ms_example").read().split("\n"))]

s.check()
# Out:
# sat

# %%
m = s.model()

W0 = [m[zW_0[i]].as_long() for i in range(16)]
W1 = [m[zW_1[i]].as_long() for i in range(16)]

from collide import sha1, expand

Q0 = sha1(expand(W0), iv)
Q1 = sha1(expand(W1), iv)

for i in range(len(cA)+10):
    print b(Q0[i]), b(Q1[i]), "%3d" % (i-4), b(Q0[i]^Q1[i]), "" if i >= len(cA) else cA[i-4]
# Out:
# 01111101001100010100100011010000 01111101001100010100100011010000  -4 00000000000000000000000000000000 ................................
# 11011100111110111100100111011100 11011100111110111100100111011100  -3 00000000000000000000000000000000 ................................
# 11100011100011101101111101000010 11100011100011101101111101000010  -2 00000000000000000000000000000000 ................................
# 01111111110101011011111001110001 01111111110101011011111001110001  -1 00000000000000000000000000000000 ...1........................0...
# 11001100001110110110011001011001 11001100001110110110011001011001   0 00000000000000000000000000000000 .^.0.1.......0.1...00.10.1..1..1
# 10001100001111100111111010111000 10011000001111100111111010111010   1 00010100000000000000000000000010 .0.+^-^^^^^^^1^0^^^11^10.0..1.+0
# 11110011111111111111111111011000 10110100000000000000000000001010   2 01000111111111111111111111010010 1-...+--------------------.-1.+0
# 01110011111111111111000101110010 00100011111111111111011110100000   3 01010000000000000000011011010010 .-.-.0.11111111111110++1+-1-00-0
# 01111110111111111111100000011101 00111110111111111111011111011111   4 01000000000000000000111111000010 .-...1.0111111111111-+++++0.1.+1
# 11011001110010111110100010101000 10011001110010111110100011111010   5 01000000000000000000000001010010 .-...0................0..+.+10+0
# 01000011011100010001010110011000 00010011011100010001010110001010   6 01010000000000000000000000010010 .-.+..................01100-.0+.
# 11001100011110100011101000001011 01001100011110100011101000001011   7 10000000000000000000000000000000 -1...1.....................0.0..
# 10110101100010010000000000000101 10100101100010010000000000000101   8 00010000000000000000000000000000 1.1-.1.......................1..
# 01111001000000000011100100000110 01011001000000000011100100000110   9 00100000000000000000000000000000 ..-..0..........................
# 00100010001110101000010001101101 00100010001110101000010001101101  10 00000000000000000000000000000000 ^...00.........................1
# 10111011010011111110100100010010 10011011010011111110100100010010  11 00100000000000000000000000000000 ..-.1..........................0
# 01101110110100011101101011000101 00101110110100011101101011000101  12 01000000000000000000000000000000 0-..1.........................!.
# 01001100010001011001100000100101 11001100010001011001100000100101  13 10000000000000000000000000000000 +..01...........................
# 10110011100000110000011111111110 10010011100000110000011111111110  14 00100000000000000000000000000000 ..-1..........................!.
# 00011100111100000010100001100000 10011100111100000010100001100000  15 10000000000000000000000000000000 +.0.1.........................!^
# 01000000000000001111100010111111 10000000000000001111100010111111  16 11000000000000000000000000000000 +-0.0.........................!.
# 00010011100111111000001111001011 10010011100111111000001111001011  17 10000000000000000000000000000000 +..1..........................^.
# 10001000011001011100110010011011 00101000011001011100110010011011  18 10100000000000000000000000000000 -.+0............................
# 11010110010001001011010001101000 01010110010001001011010001101000  19 10000000000000000000000000000000 -...m...........................
# 01000011101111010000000110101101 01100011101111010000000110101101  20 00100000000000000000000000000000 ..+.r...........................
# 00010011101001101110111111100101 00010011101001101110111111100101  21 00000000000000000000000000000000 ^.r.m...........................
# 11010111111011010000111010011001 11110111111011010000111010011001  22 00100000000000000000000000000000 ..+.r...........................
# 10010000110110101001111010000100 00010000110110101001111010000100  23 10000000000000000000000000000000 -...m..........................!
# 01000101111100011111101110000101 00100101111100011111101110000101  24 01100000000000000000000000000000 .-+.R...........................
# 11000001010000101000111010010011 11000001010000101000111010010011  25 00000000000000000000000000000000 ..r##...........................
# 01000011010100000010010100001011 01010011010100000010010100001011  26 00010000000000000000000000000000 ...rr...........................
# 11100010100010100100001010011101 01010010100010100100001010011111  27 10110000000000000000000000000010 -...............................
# 11100000001100110001000110011011 01010000001100110001000111011001  28 10110000000000000000000001000010 -.#.............................
# 00000101110000101101001011101010 00011001110000101101101010000110  29 00011100000000000000100001101100 ................................
# 01010101100011110110111100001001 00111101100100000110001001001010  30 01101000000111110000110101000011 ..R.............................
# 11111010100001010100100000000011 00010010101000111011100001001100  31 11101000001001101111000001001111
# 11011000101100110001000000000110 11111011011110100000100111010001  32 00100011110010010001100111010111
# 10011011100101000001011101001010 00011101100101000011111111000010  33 10000110000000000010100010001000
# 00011011010001010000110011010000 11011101100011111000001100110011  34 11000110110010101000111111100011
# 11011100100010001001011110111001 11110100101000000111001101101011  35 00101000001010001110010011010010
# 01010100000101110011000010011001 01110101110000011000010010100011  36 00100001110101101011010000111010
# 01100010011010011101110100001110 01001000010011111110011111001101  37 00101010001001100011101011000011
# 01101001000101100101100101100010 00111111111111011101110111001111  38 01010110111010111000010010101101
# 00011001111111111101111100011101 00001111010011000110111110111000  39 00010110101100111011000010100101
# 10001000010010010011001011100000 11100011111101011010000000110111  40 01101011101111001001001011010111

# %%
g = Goal()

[encode_characteristic(g, rnd+4, zA_0, zA_1, cA[rnd]) for rnd in cA]
[encode_characteristic(g, rnd+0, zW_0, zW_1, cW[rnd]) for rnd in cW]

[g.add(zA_0[i] == iv[i]) for i in range(5)]

t = Then('simplify', 'bit-blast', 'tseitin-cnf')
subgoal = t(g)
assert len(subgoal) == 1

"""
f = open("formula", "w")
for c in subgoal[0]:
    f.write(str(c) + "\n")
f.close()    
"""
"""


W0 = []
W1 = []

for i in range(16):
    w0 = m[zW_0[i]].as_long()
    w1 = m[zW_1[i]].as_long()
    W0.append(w0)
    W1.append(w1)
    print b(w0), b(w1), "    ", b(w0^w1)
"""
pass

# %%
"""
for i in range(3):
    mask, b0, b1 = encode_characteristic(s, i, zW_0, zW_1, cW[i])
    print i
    print b(mask)
    print b(b0)
"""

"""
rnd = 0
for a in open("ms_example").read().split("\n"):
    #if len(zA_0) <= rnd:
        #break
    if rnd >= 5:
        break
    s.add(zA_0[rnd] == int(a, 2))
    rnd += 1
"""

# %%
# Out:
# Or(k!46533, Not(k!46565))
