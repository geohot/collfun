# %%
from z3 import *
def b(x):
    return bin(x)[2:].rjust(32, '0')

cA = {}
cW = {}

# 0, 1, +, -: self explanatory
# x: flip the bit
# ^: Qt[b] == Qt-1[b]
# !: Qt[b] != Qt-1[b]
# r: Qt[b] == RL(Qt-1,30)[b]
# R: Qt[b] != RL(Qt-1,30)[b]
# m: Qt[b] == RL(Qt-2,30)[b]
# #: Qt[b] != RL(Qt-2,30)[b]


for ln in open('ms_char').read().split("\n"):
    lnn = ln.split(" ")
    if len(lnn) > 1:
        rnd = int(lnn[0][:-1])
        cA[rnd] = lnn[1]
        if len(lnn) == 3:
            cW[rnd] = lnn[2]
        print lnn

#print cA
#print W
# Out:
# ['-4:', '................................']
# ['-3:', '................................']
# ['-2:', '................................']
# ['-1:', '...1........................0...']
# ['0:', '.^.0.1.......0.1...00.10.1..1..1', '....++........................+.']
# ['1:', '.0.+^-^^^^^^^1^0^^^11^10.0..1.+0', 'x-.........................-....']
# ['2:', '1-...+--------------------.-1.+0', 'x.++.-.....................-+-..']
# ['3:', '.-.-.0.11111111111110++1+-1-00-0', '..-+++.......................-..']
# ['4:', '.-...1.0111111111111-+++++0.1.+1', 'x.---+.....................+-.+.']
# ['5:', '.-...0................0..+.+10+0', '..-........................-....']
# ['6:', '.-.+..................01100-.0+.', '..-..+.....................+++..']
# ['7:', '-1...1.....................0.0..', 'x++.--.....................+.+..']
# ['8:', '1.1-.1.......................1..', '....-+........................-.']
# ['9:', '..-..0..........................', 'x+.........................-....']
# ['10:', '^...00.........................1', 'x.+-.-.....................+--..']
# ['11:', '..-.1..........................0', '..-.+-.......................+..']
# ['12:', '0-..1.........................!.', 'x.+---.....................+-...']
# ['13:', '+..01...........................', 'x.++.......................-....']
# ['14:', '..-1..........................!.', '............................+-..']
# ['15:', '+.0.1.........................!^', 'x.---......................-....']
# ['16:', '+-0.0.........................!.', '....-......................-+...']
# ['17:', '+..1..........................^.', '.+---......................-....']
# ['18:', '-.+0............................', '....-......................+.-..']
# ['19:', '-...m...........................', '.-++.......................+....']
# ['20:', '..+.r...........................', 'x.-+-......................-++..']
# ['21:', '^.r.m...........................', 'x++.-...........................']
# ['22:', '..+.r...........................', 'x.++.........................-..']
# ['23:', '-...m..........................!', '.-.++......................+....']
# ['24:', '.-+.R...........................', 'x.-+........................+-..']
# ['25:', '..r##...........................', '.-..+...........................']
# ['26:', '...rr...........................', 'x.+-............................']
# ['27:', '-...............................']
# ['28:', '-.#.............................']
# ['29:', '................................']
# ['30:', '..R.............................']

# %%
# encode characteristics
def encode_characteristic(s, rnd, z0, z1, char):
    if len(z0) <= rnd:
        return
    mask = 0
    nnmask = 0
    b0 = 0
    b1 = 0
    for i in range(32):
        c = char[31-i]
        if c == "0":
            mask |= 1<<i
        elif c == "1":
            b0 |= 1<<i
            b1 |= 1<<i
            mask |= 1<<i
        elif c == "-":
            b0 |= 1<<i
            mask |= 1<<i
        elif c == "+":
            b1 |= 1<<i
            mask |= 1<<i
        elif c == "x":
            s.add((z0[rnd]&(1<<i)) != (z1[rnd]&(1<<i)))
            nnmask |= 1<<i
        """
        elif c == "^": # ^: Qt[b] == Qt-1[b]
            s.add((z0[rnd]&(1<<i)) == (z0[rnd-1]&(1<<i)))
            s.add((z1[rnd]&(1<<i)) == (z1[rnd-1]&(1<<i)))
            nnmask |= 1<<i
        elif c == "!": # !: Qt[b] != Qt-1[b]
            s.add((z0[rnd]&(1<<i)) != (z0[rnd-1]&(1<<i)))
            s.add((z1[rnd]&(1<<i)) != (z1[rnd-1]&(1<<i)))
            nnmask |= 1<<i
        elif c == "r": # ^: Qt[b] == RL(Qt-1,30)[b]
            s.add((z0[rnd]&(1<<i)) == (z0[rnd-1]&(1<<((i+30) % 32))))
            s.add((z1[rnd]&(1<<i)) == (z1[rnd-1]&(1<<((i+30) % 32))))
            nnmask |= 1<<i
        elif c == "R": # !: Qt[b] != RL(Qt-1,30)[b]
            s.add((z0[rnd]&(1<<i)) == (z0[rnd-1]&(1<<((i+30) % 32))))
            s.add((z1[rnd]&(1<<i)) == (z1[rnd-1]&(1<<((i+30) % 32))))
            nnmask |= 1<<i
        elif c == "m": # ^: Qt[b] == RL(Qt-2,30)[b]
            s.add((z0[rnd]&(1<<i)) == (z0[rnd-2]&(1<<((i+30) % 32))))
            s.add((z1[rnd]&(1<<i)) == (z1[rnd-2]&(1<<((i+30) % 32))))
            nnmask |= 1<<i
        elif c == "#": # !: Qt[b] != RL(Qt-2,30)[b]
            s.add((z0[rnd]&(1<<i)) == (z0[rnd-2]&(1<<((i+30) % 32))))
            s.add((z1[rnd]&(1<<i)) == (z1[rnd-2]&(1<<((i+30) % 32))))
            nnmask |= 1<<i
        """

    nmask = mask ^ 0xFFFFFFFF
    nmask &= nnmask ^ 0xFFFFFFFF
    
    # need to encode ^ and !
    s.add((z0[rnd]&mask) == b0)
    s.add((z1[rnd]&mask) == b1)
    
    s.add(z0[rnd]&nmask == z1[rnd]&nmask)
    
    return mask, b0, b1


# encode rules of SHA-1
def encode_sha1(a, w, f, count):
    for i in range(count):
        # encode w
        if i >= 16:
            w.append(RotateLeft(w[-3] ^ w[-8] ^ w[-14] ^ w[-16], 1))
            pass
        
        # encode f
        b = a[-2]
        c = RotateLeft(a[-3], 30)
        d = RotateLeft(a[-4], 30)
        
        if i < 20:
            # if
            f.append(d ^ (b & (c ^ d)))
        elif i < 40 or i >= 60:
            # xor
            f.append(b ^ c ^ d)
        else:
            # maj
            f.append((b&c) ^ (b&d) ^ (c&d))
        
        k = [0x5a827999, 0x6ed9eba1, 0x8f1bbcdc, 0xca62c1d6][i/20]
            
        # encode a
        temp = RotateLeft(a[-1], 5) + f[-1] + RotateLeft(a[-5], 30) + w[i] + k
        a.append(temp)

# %%
# create the variables

zF_0 = []
zF_1 = []

zW_0 = []
zW_1 = []
for i in range(16):
    zW_0.append(BitVec('W_0_%d' % i, 32))
    zW_1.append(BitVec('W_1_%d' % i, 32))

zA_0 = []
zA_1 = []
for i in range(-4, 1):
    zA_0.append(BitVec('A_0_%d' % i, 32))
    zA_1.append(BitVec('A_1_%d' % i, 32))
    
encode_sha1(zA_0, zW_0, zF_0, 30)
encode_sha1(zA_1, zW_1, zF_1, 30)

# %%
# test sha-1
s = Solver()

iv = [0b01111101001100010100100011010000,
      0b11011100111110111100100111011100,
      0b11100011100011101101111101000010,
      0b01111111110101011011111001110001,
      0b11001100001110110110011001011001]

[encode_characteristic(s, rnd+4, zA_0, zA_1, cA[rnd]) for rnd in cA]
[encode_characteristic(s, rnd+0, zW_0, zW_1, cW[rnd]) for rnd in cW]

[s.add(zA_0[i] == iv[i]) for i in range(5)]

#[s.add(zA_0[rnd] == int(a, 2)) for rnd, a in zip(range(len(zA_0)), open("ms_example").read().split("\n"))]

pass

# %%
s.check()
m = s.model()

W0 = [m[zW_0[i]].as_long() for i in range(16)]
W1 = [m[zW_1[i]].as_long() for i in range(16)]

from collide import sha1, expand

Q0 = sha1(expand(W0), iv)
Q1 = sha1(expand(W1), iv)

for i in range(len(cA)+10):
    print b(Q0[i]), b(Q1[i]), "%3d" % (i-4), b(Q0[i]^Q1[i]), "" if i >= len(cA) else cA[i-4]
# Out:
# 01111101001100010100100011010000 01111101001100010100100011010000  -4 00000000000000000000000000000000 ................................
# 11011100111110111100100111011100 11011100111110111100100111011100  -3 00000000000000000000000000000000 ................................
# 11100011100011101101111101000010 11100011100011101101111101000010  -2 00000000000000000000000000000000 ................................
# 01111111110101011011111001110001 01111111110101011011111001110001  -1 00000000000000000000000000000000 ...1........................0...
# 11001100001110110110011001011001 11001100001110110110011001011001   0 00000000000000000000000000000000 .^.0.1.......0.1...00.10.1..1..1
# 10101100001111100111111000111000 10111000001111100111111000111010   1 00010100000000000000000000000010 .0.+^-^^^^^^^1^0^^^11^10.0..1.+0
# 11110011111111111111111111011100 10110100000000000000000000001110   2 01000111111111111111111111010010 1-...+--------------------.-1.+0
# 11010011111111111111000101110010 10000011111111111111011110100000   3 01010000000000000000011011010010 .-.-.0.11111111111110++1+-1-00-0
# 01111110111111111111100000011001 00111110111111111111011111011011   4 01000000000000000000111111000010 .-...1.0111111111111-+++++0.1.+1
# 01100001111111100101000000001000 00100001111111100101000001011010   5 01000000000000000000000001010010 .-...0................0..+.+10+0
# 11101010000000011000000110010000 10111010000000011000000110000010   6 01010000000000000000000000010010 .-.+..................01100-.0+.
# 11010110001100000011010110100010 01010110001100000011010110100010   7 10000000000000000000000000000000 -1...1.....................0.0..
# 11111111010011011000101010111110 11101111010011011000101010111110   8 00010000000000000000000000000000 1.1-.1.......................1..
# 00111010001111101001111100001001 00011010001111101001111100001001   9 00100000000000000000000000000000 ..-..0..........................
# 01110010001000101000100101000101 01110010001000101000100101000101  10 00000000000000000000000000000000 ^...00.........................1
# 10111000110110101010000011100000 10011000110110101010000011100000  11 00100000000000000000000000000000 ..-.1..........................0
# 01011111100110100111111111010010 00011111100110100111111111010010  12 01000000000000000000000000000000 0-..1.........................!.
# 00001010000000000001101100011110 10001010000000000001101100011110  13 10000000000000000000000000000000 +..01...........................
# 01111010010001111111101000100101 01011010010001111111101000100101  14 00100000000000000000000000000000 ..-1..........................!.
# 01001000000000000111100010010011 11001000000000000111100010010011  15 10000000000000000000000000000000 +.0.1.........................!^
# 01010000011010000001001110100000 10010000011010000001001110100000  16 11000000000000000000000000000000 +-0.0.........................!.
# 01010110010111001111111110001100 11010110010111001111111110001100  17 10000000000000000000000000000000 +..1..........................^.
# 11000000001010000110011010001111 01100000001010000110011010001111  18 10100000000000000000000000000000 -.+0............................
# 10000001100100110000110100001111 00000001100100110000110100001111  19 10000000000000000000000000000000 -...m...........................
# 11000000100011101011100100010110 11100000100011101011100100010110  20 00100000000000000000000000000000 ..+.r...........................
# 11100110101101110111110100100000 11100110101101110111110100100000  21 00000000000000000000000000000000 ^.r.m...........................
# 11001100000100000010001010011100 11101100000100000010001010011100  22 00100000000000000000000000000000 ..+.r...........................
# 00010110100110111011011000010111 00110110100110111011011000010111  23 00100000000000000000000000000000 -...m..........................!
# 00101000000111110011100001111110 01011000000111110011100010010010  24 01110000000000000000000011101100 .-+.R...........................
# 00101110011110100101110011000101 10111110011110100101111101010111  25 10010000000000000000001110010010 ..r##...........................
# 10011101101110000010010000110001 00110101101110000111011011010111  26 10101000000000000101001011100110 ...rr...........................
# 11100000000100111001000110111000 11011100000111011110010000000010  27 00111100000011100111010110111010 -...............................
# 00011110001000110000100001111001 00111111011011010000001110101111  28 00100001010011100000101111010110 -.#.............................
# 10110111001111000001000111011000 10100110100001011101011101101110  29 00010001101110011100011010110110 ................................
# 11110000001110110110101001100101 00100001001011101001111111000110  30 11010001000101011111010110100011 ..R.............................
# 01010110011010101010110100000111 11110000011110110010010010010011  31 10100110000100011000100110010100
# 00111010010100111111010001111010 10101000001111010111100110001001  32 10010010011011101000110111110011
# 10001010000001100110011101101000 10111001011100000000101011110100  33 00110011011101100110110110011100
# 01110101110011100101111101011100 10100111011101011101010000000001  34 11010010101110111000101101011101
# 00001110100111100110010000101110 10101110001000110011001010110111  35 10100000101111010101011010011001
# 10100010010111110100111000000000 11000010110010001000101001011101  36 01100000100101111100010001011101
# 11101111111111001000000000000011 01110000110101000100011111100010  37 10011111001010001100011111100001
# 00110101100111000111101110101101 01000000100000011101001101110101  38 01110101000111011010100011011000
# 10101000011110010111011110110101 11111000101100000010110101000000  39 01010000110010010101101011110101
# 00110101100101010101011111000001 01001001010111111001010010111010  40 01111100110010101100001101111011

# %%
g = Goal()

[encode_characteristic(g, rnd+4, zA_0, zA_1, cA[rnd]) for rnd in cA]
[encode_characteristic(g, rnd+0, zW_0, zW_1, cW[rnd]) for rnd in cW]

[g.add(zA_0[i] == iv[i]) for i in range(5)]

t = Then('simplify', 'bit-blast', 'tseitin-cnf')
subgoal = t(g)
assert len(subgoal) == 1

sg = subgoal[0]
#sg = sg.simplify()

pass

# %%
def proc(aa):
    aa = str(aa)
    ret = []
    for a in aa.split(","):
        #print a
        vn = int(a.split("!")[1].strip(")")) + 1
        if "Not" in a:
            vn *= -1
        ret.append(vn)
    return ret

cnf = map(proc, sg)

# %%
abs_flat_cnf = map(abs, [item for sublist in cnf for item in sublist])

ll = list(set(abs_flat_cnf))
ll_0 = zip(ll, range(1, len(ll)+1))
ll_1 = zip(map(lambda x: x*-1, ll), map(lambda x: x*-1, range(1, len(ll)+1)))
repl = dict(ll_0 + ll_1)
varcount = len(ll)
print "vars", varcount

ncnf = [[repl[k] for k in c] for c in cnf]
# Out:
# vars 41030

# %%
f = open("formula_30", "w")
f.write("p cnf %d %d\n" % (varcount, len(ncnf)))
for c in ncnf:
    f.write(' '.join(map(str, c)) + " 0\n")
f.close()

# %%
"""
for i in range(3):
    mask, b0, b1 = encode_characteristic(s, i, zW_0, zW_1, cW[i])
    print i
    print b(mask)
    print b(b0)
"""

"""
rnd = 0
for a in open("ms_example").read().split("\n"):
    #if len(zA_0) <= rnd:
        #break
    if rnd >= 5:
        break
    s.add(zA_0[rnd] == int(a, 2))
    rnd += 1
"""

# %%
print cnf[2], ncnf[2]
# Out:
# [59451, -59483] [2, -34]
